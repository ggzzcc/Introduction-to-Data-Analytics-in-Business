# %%
import pandas as pd

# %%
file1 = 'edu_2015.csv' # 88 county
file2 = 'data.csv'     # 50 county

# %%
df1 = pd.read_csv(file1)

# %%
df1.head(5)
# Out:
#            GEO_ID                    NAME  \
# 0              id    Geographic Area Name
# 1  0500000US39001      Adams County, Ohio
# 2  0500000US39003      Allen County, Ohio
# 3  0500000US39005    Ashland County, Ohio
# 4  0500000US39007  Ashtabula County, Ohio
#
#                                S1501_C01_001E  \
# 0  Total!!Estimate!!Population 18 to 24 years
# 1                                        2157
# 2                                       11124
# 3                                        5731
# 4                                        7997
#
#                                       S1501_C01_001M  \
# 0  Total!!Margin of Error!!Population 18 to 24 years
# 1                                                 60
# 2                                                137
# 3                                                 91
# 4                                                133
#
#                                       S1501_C01_002E  \
# ...

# %%
new_df = df1.copy()
new_df.head()
# Out:
#            GEO_ID                    NAME  \
# 0              id    Geographic Area Name
# 1  0500000US39001      Adams County, Ohio
# 2  0500000US39003      Allen County, Ohio
# 3  0500000US39005    Ashland County, Ohio
# 4  0500000US39007  Ashtabula County, Ohio
#
#                                S1501_C01_001E  \
# 0  Total!!Estimate!!Population 18 to 24 years
# 1                                        2157
# 2                                       11124
# 3                                        5731
# 4                                        7997
#
#                                       S1501_C01_001M  \
# 0  Total!!Margin of Error!!Population 18 to 24 years
# 1                                                 60
# 2                                                137
# 3                                                 91
# 4                                                133
#
#                                       S1501_C01_002E  \
# ...

# %%
def delete_ohio(x):
    if x[-4:] == 'Ohio':
        return x[:-6]
    return x

# %%
new_df['NAME'] = new_df['NAME'].apply(delete_ohio)

# %%
new_df
# Out:
#             GEO_ID                  NAME  \
# 0               id  Geographic Area Name
# 1   0500000US39001          Adams County
# 2   0500000US39003          Allen County
# 3   0500000US39005        Ashland County
# 4   0500000US39007      Ashtabula County
# ..             ...                   ...
# 84  0500000US39167     Washington County
# 85  0500000US39169          Wayne County
# 86  0500000US39171       Williams County
# 87  0500000US39173           Wood County
# 88  0500000US39175        Wyandot County
#
#                                 S1501_C01_001E  \
# 0   Total!!Estimate!!Population 18 to 24 years
# 1                                         2157
# 2                                        11124
# 3                                         5731
# 4                                         7997
# ..                                         ...
# 84                                        5637
# 85                                       11631
# ...

# %%
def delete_OH(x):
    if x[-2:] == 'OH':
        return x[:-4]
    return x

# def delete_OH(x):
#     return type(x)

# %%
df2 = pd.read_csv('data.csv')
df2 = df2[df2.County.notnull()]
df2
# Out:
#      Unnamed: 0  Year                 County  Deaths  Population  Crude Rate  \
# 0             0  2015       Adams County, OH      13       22006  Unreliable
# 1             1  2015       Allen County, OH      21       82914        25.3
# 2             2  2015   Ashtabula County, OH      24       79192        30.3
# 3             3  2015     Belmont County, OH      18       57540  Unreliable
# 4             4  2015       Brown County, OH      26       34930        74.4
# ..          ...   ...                    ...     ...         ...         ...
# 245         245  2019  Tuscarawas County, OH      15       73440  Unreliable
# 246         246  2019      Warren County, OH      48      185077        25.9
# 247         247  2019  Washington County, OH      11       49557  Unreliable
# 248         248  2019       Wayne County, OH      24       90983        26.4
# 249         249  2019        Wood County, OH      27      107311        25.2
#
# ...

# %%
df2['County'].apply(delete_OH)
# Out:
# 0           Adams County
# 1           Allen County
# 2       Ashtabula County
# 3         Belmont County
# 4           Brown County
#              ...
# 245    Tuscarawas County
# 246        Warren County
# 247    Washington County
# 248         Wayne County
# 249          Wood County
# Name: County, Length: 250, dtype: object

# %%
df2['County'] = df2['County'].apply(delete_OH)
df2
# Out:
#      Unnamed: 0  Year             County  Deaths  Population  Crude Rate  \
# 0             0  2015       Adams County      13       22006  Unreliable
# 1             1  2015       Allen County      21       82914        25.3
# 2             2  2015   Ashtabula County      24       79192        30.3
# 3             3  2015     Belmont County      18       57540  Unreliable
# 4             4  2015       Brown County      26       34930        74.4
# ..          ...   ...                ...     ...         ...         ...
# 245         245  2019  Tuscarawas County      15       73440  Unreliable
# 246         246  2019      Warren County      48      185077        25.9
# 247         247  2019  Washington County      11       49557  Unreliable
# 248         248  2019       Wayne County      24       90983        26.4
# 249         249  2019        Wood County      27      107311        25.2
#
#      Crude Rate Lower 95% Confidence Interval  \
# ...

# %%
county = df2.County.unique()

# %%
type(county)
# Out:
# numpy.ndarray

# %%
len(county)
# Out:
# 50

# %%
fileter = new_df.NAME.apply(lambda x: x in county)

# %%
final = new_df.copy()[fileter]

# %%
final = final.iloc[:, :-1]
final
# Out:
#             GEO_ID               NAME S1501_C01_001E S1501_C01_001M  \
# 1   0500000US39001       Adams County           2157             60
# 2   0500000US39003       Allen County          11124            137
# 4   0500000US39007   Ashtabula County           7997            133
# 7   0500000US39013     Belmont County           5408            113
# 8   0500000US39015       Brown County           3418             71
# 9   0500000US39017      Butler County          44576            126
# 12  0500000US39023       Clark County          12241             58
# 13  0500000US39025    Clermont County          16159            173
# 14  0500000US39027     Clinton County           4033            112
# 15  0500000US39029  Columbiana County           8067            132
# 18  0500000US39035    Cuyahoga County         115133             42
# 19  0500000US39037       Darke County           3993             44
# 21  0500000US39041    Delaware County          13292            118
# ...

# %%
final
# Out:
#             GEO_ID               NAME S1501_C01_001E S1501_C01_001M  \
# 1   0500000US39001       Adams County           2157             60
# 2   0500000US39003       Allen County          11124            137
# 4   0500000US39007   Ashtabula County           7997            133
# 7   0500000US39013     Belmont County           5408            113
# 8   0500000US39015       Brown County           3418             71
# 9   0500000US39017      Butler County          44576            126
# 12  0500000US39023       Clark County          12241             58
# 13  0500000US39025    Clermont County          16159            173
# 14  0500000US39027     Clinton County           4033            112
# 15  0500000US39029  Columbiana County           8067            132
# 18  0500000US39035    Cuyahoga County         115133             42
# 19  0500000US39037       Darke County           3993             44
# 21  0500000US39041    Delaware County          13292            118
# ...

# %%
s = ['S1501_C01_002E',
     'S1501_C01_007E',
     'S1501_C01_008E']

# %%
test = final[s]
test = test.reset_index(drop=True)

# %%
test.head()
# Out:
#   S1501_C01_002E S1501_C01_007E S1501_C01_008E
# 0            356           1451           2760
# 1           1859           1509           5892
# 2           2029           3021           7011
# 3            980           1206           4136
# 4            259           1211           3690

# %%
type(test['S1501_C01_002E'].values[0])
# Out:
# str

# %%
test['S1501_C01_002E'] = test['S1501_C01_002E'].astype(int)
test['S1501_C01_007E'] = test['S1501_C01_007E'].astype(int)
test['S1501_C01_008E'] = test['S1501_C01_008E'].astype(int)

# %%
type(test['S1501_C01_002E'].values[0])
# Out:
# numpy.int64

# %%
test['sum'] = test.sum(axis=1)

# %%
test.head()
# Out:
#    S1501_C01_002E  S1501_C01_007E  S1501_C01_008E    sum
# 0             356            1451            2760   4567
# 1            1859            1509            5892   9260
# 2            2029            3021            7011  12061
# 3             980            1206            4136   6322
# 4             259            1211            3690   5160

# %%
test
# Out:
#     S1501_C01_002E  S1501_C01_007E  S1501_C01_008E     sum
# 0              356            1451            2760    4567
# 1             1859            1509            5892    9260
# 2             2029            3021            7011   12061
# 3              980            1206            4136    6322
# 4              259            1211            3690    5160
# 5             4235            7203           17430   28868
# 6             1965            3226            9078   14269
# 7             1964            4138           10020   16122
# 8              607             815            2516    3938
# 9             1449            2095            7657   11201
# 10           19730           27430           77278  124438
# 11             555             876            3311    4742
# 12            1704             950            3109    5763
# 13             730            1196            4079    6005
# 14            2141            2149            6128   10418
# ...

# %%
df2['education: less_than_high_school'] = test['sum']

# %%
df2
# Out:
#      Unnamed: 0  Year             County  Deaths  Population  Crude Rate  \
# 0             0  2015       Adams County      13       22006  Unreliable
# 1             1  2015       Allen County      21       82914        25.3
# 2             2  2015   Ashtabula County      24       79192        30.3
# 3             3  2015     Belmont County      18       57540  Unreliable
# 4             4  2015       Brown County      26       34930        74.4
# ..          ...   ...                ...     ...         ...         ...
# 245         245  2019  Tuscarawas County      15       73440  Unreliable
# 246         246  2019      Warren County      48      185077        25.9
# 247         247  2019  Washington County      11       49557  Unreliable
# 248         248  2019       Wayne County      24       90983        26.4
# 249         249  2019        Wood County      27      107311        25.2
#
#      Crude Rate Lower 95% Confidence Interval  \
# ...

# %%
#edu_2016 data cleaning

# %%
def delete_ohio(x):
    if x[-4:] == 'Ohio':
        return x[:-6]
    return x

# %%
def extract(file):
    
    def delete_ohio(x):
        if x[-4:] == 'Ohio':
            return x[:-6]
        return x
    
    df = pd.read_csv(file)
    df['NAME'] = df['NAME'].apply(delete_ohio)
    
    
    fileter = df.NAME.apply(lambda x: x in county) #county = df2.County.unique()
    final = df.copy()[fileter]
    final = final.iloc[:, :-1]
    
    cols = ['S1501_C01_002E','S1501_C01_007E','S1501_C01_008E']
    result = final[cols]
    result = result.reset_index(drop=True)
    
    result['S1501_C01_002E'] = result['S1501_C01_002E'].astype(int)
    result['S1501_C01_007E'] = result['S1501_C01_007E'].astype(int)
    result['S1501_C01_008E'] = result['S1501_C01_008E'].astype(int)
    result['sum'] = result.sum(axis=1) 
    
    return pd.DataFrame(result['sum'])

# %%
extract('edu_2016.csv').head()
# Out:
#      sum
# 0   4504
# 1   9200
# 2  12014
# 3   5994
# 4   4766

# %%
files = ['edu_2015.csv', 'edu_2016.csv', 'edu_2017.csv',
         'edu_2018.csv', 'edu_2019.csv']

# %%
extract('edu_2017.csv')
# Out:
#        sum
# 0     4311
# 1     9402
# 2    11849
# 3     5670
# 4     4485
# 5    27430
# 6    13552
# 7    15850
# 8     3716
# 9    10877
# 10  112900
# 11    4375
# 12    5968
# 13    5121
# 14   10200
# 15   92163
# 16    4304
# 17    8334
# 18    9261
# 19   61102
# 20    4345
# 21    5896
# 22    5189
# 23    4330
# 24   15395
# 25    6869
# 26   13513
# 27    3748
# 28   26380
# 29   39842
# 30   18856
# 31    6883
# 32    9006
# 33    8555
# 34   43732
# 35    8232
# 36   10476
# 37    3510
# 38   13314
# 39    8513
# 40    4824
# 41    9745
# 42   28258
# 43   39335
# 44   19115
# 45   10159
# 46   12875
# 47    4983
# 48   13000
# 49    5776

# %%
def combine(files, answer=None):
    is_first = True
    for f in files:
        if is_first:
            is_first = False
            answer =extract(f)
        else:
            answer = pd.concat([answer, extract(f)])
    answer = answer.reset_index(drop=True)
    return answer

# %%
df2 = df2.reset_index(drop=True)

# %%
combine(files)
# Out:
#        sum
# 0     4567
# 1     9260
# 2    12061
# 3     6322
# 4     5160
# ..     ...
# 245  10455
# 246  12201
# 247   4773
# 248  12489
# 249   5501
#
# [250 rows x 1 columns]

# %%
df2['edu'] = combine(files)

# %%
df2
# Out:
#      Unnamed: 0  Year             County  Deaths  Population  Crude Rate  \
# 0             0  2015       Adams County      13       22006  Unreliable
# 1             1  2015       Allen County      21       82914        25.3
# 2             2  2015   Ashtabula County      24       79192        30.3
# 3             3  2015     Belmont County      18       57540  Unreliable
# 4             4  2015       Brown County      26       34930        74.4
# ..          ...   ...                ...     ...         ...         ...
# 245         245  2019  Tuscarawas County      15       73440  Unreliable
# 246         246  2019      Warren County      48      185077        25.9
# 247         247  2019  Washington County      11       49557  Unreliable
# 248         248  2019       Wayne County      24       90983        26.4
# 249         249  2019        Wood County      27      107311        25.2
#
#      Crude Rate Lower 95% Confidence Interval  \
# ...

# %%
df2['education: less_than_high_school'] = df2['edu']
df2 = df2.drop(columns='edu')
df2
# Out:
#      Unnamed: 0  Year             County  Deaths  Population  Crude Rate  \
# 0             0  2015       Adams County      13       22006  Unreliable
# 1             1  2015       Allen County      21       82914        25.3
# 2             2  2015   Ashtabula County      24       79192        30.3
# 3             3  2015     Belmont County      18       57540  Unreliable
# 4             4  2015       Brown County      26       34930        74.4
# ..          ...   ...                ...     ...         ...         ...
# 245         245  2019  Tuscarawas County      15       73440  Unreliable
# 246         246  2019      Warren County      48      185077        25.9
# 247         247  2019  Washington County      11       49557  Unreliable
# 248         248  2019       Wayne County      24       90983        26.4
# 249         249  2019        Wood County      27      107311        25.2
#
#      Crude Rate Lower 95% Confidence Interval  \
# ...

# %%
xs = ['Population', 'Divorce Count', 'education: less than high school', 'household: homeless', 'household: foster kids', 'houshold: people living alone']

# %%
household_2015 = 'household_2015.csv' # 88 county
# # file2 = 'data.csv'     # 50 county
household_2016 = 'household_2016.csv' # 88 county
household_2017 = 'household_2017.csv' # 88 county
household_2018 = 'household_2018.csv' # 88 county
household_2019 = 'household_2019.csv' # 88 county

# %%
# household 2015 data cleaning

# %%
dfhh15 = pd.read_csv(household_2015)

# %%
dfhh15.head(5)
# Out:
#            GEO_ID                    NAME      B09019_001E  \
# 0              id    Geographic Area Name  Estimate!!Total
# 1  0500000US39001      Adams County, Ohio            28229
# 2  0500000US39003      Allen County, Ohio           105196
# 3  0500000US39005    Ashland County, Ohio            53189
# 4  0500000US39007  Ashtabula County, Ohio            99777
#
#               B09019_001M                     B09019_002E  \
# 0  Margin of Error!!Total  Estimate!!Total!!In households
# 1                   *****                           27847
# 2                   *****                          101279
# 3                   *****                           51065
# 4                   *****                           96275
#
#                              B09019_002M  \
# 0  Margin of Error!!Total!!In households
# 1                                    124
# 2                                    485
# 3                                    244
# 4                                    330
#
# ...

# %%
new_dfhh15 = dfhh15.copy()
new_dfhh15.head()
# Out:
#            GEO_ID                    NAME      B09019_001E  \
# 0              id    Geographic Area Name  Estimate!!Total
# 1  0500000US39001      Adams County, Ohio            28229
# 2  0500000US39003      Allen County, Ohio           105196
# 3  0500000US39005    Ashland County, Ohio            53189
# 4  0500000US39007  Ashtabula County, Ohio            99777
#
#               B09019_001M                     B09019_002E  \
# 0  Margin of Error!!Total  Estimate!!Total!!In households
# 1                   *****                           27847
# 2                   *****                          101279
# 3                   *****                           51065
# 4                   *****                           96275
#
#                              B09019_002M  \
# 0  Margin of Error!!Total!!In households
# 1                                    124
# 2                                    485
# 3                                    244
# 4                                    330
#
# ...

# %%
def delete_ohio(x):
    if x[-4:] == "Ohio":
        return x[:-6]
    return x

# %%
new_dfhh15['NAME'] = new_dfhh15['NAME'].apply(delete_ohio)

# %%
new_dfhh15
# Out:
#             GEO_ID                  NAME      B09019_001E  \
# 0               id  Geographic Area Name  Estimate!!Total
# 1   0500000US39001          Adams County            28229
# 2   0500000US39003          Allen County           105196
# 3   0500000US39005        Ashland County            53189
# 4   0500000US39007      Ashtabula County            99777
# ..             ...                   ...              ...
# 84  0500000US39167     Washington County            61351
# 85  0500000US39169          Wayne County           115371
# 86  0500000US39171       Williams County            37386
# 87  0500000US39173           Wood County           128885
# 88  0500000US39175        Wyandot County            22467
#
#                B09019_001M                     B09019_002E  \
# 0   Margin of Error!!Total  Estimate!!Total!!In households
# 1                    *****                           27847
# 2                    *****                          101279
# ...

# %%
county = df2.County.unique()

# %%
type(county)
# Out:
# numpy.ndarray

# %%
len(county)
# Out:
# 50

# %%
fileter = new_dfhh15.NAME.apply(lambda x: x in county)

# %%
final = new_dfhh15.copy()[fileter]

# %%
final = final.iloc[:, :-1]
final
# Out:
#             GEO_ID               NAME B09019_001E B09019_001M B09019_002E  \
# 1   0500000US39001       Adams County       28229       *****       27847
# 2   0500000US39003       Allen County      105196       *****      101279
# 4   0500000US39007   Ashtabula County       99777       *****       96275
# 7   0500000US39013     Belmont County       69560       *****       65516
# 8   0500000US39015       Brown County       44247       *****       43666
# 9   0500000US39017      Butler County      372538       *****      361240
# 12  0500000US39023       Clark County      136827       *****      133703
# 13  0500000US39025    Clermont County      200285       *****      198484
# 14  0500000US39027     Clinton County       41892       *****       40672
# 15  0500000US39029  Columbiana County      105987       *****      102214
# 18  0500000US39035    Cuyahoga County     1263189       *****     1234454
# 19  0500000US39037       Darke County       52356       *****       51671
# ...

# %%
s = ['B09019_022E']

# %%
test = final[s]
test = test.reset_index(drop=True)

# %%
test.head
# Out:
# <bound method NDFrame.head of    B09019_022E
# 0            4
# 1            0
# 2           54
# 3           19
# 4           12
# 5          167
# 6           76
# 7          145
# 8           47
# 9          106
# 10         578
# 11          42
# 12          88
# 13           1
# 14          99
# 15         531
# 16          15
# 17          39
# 18          56
# 19         851
# 20          11
# 21          40
# 22          81
# 23          10
# 24          55
# 25          23
# 26         183
# 27          28
# 28         146
# 29         299
# 30         169
# 31          34
# 32          47
# 33          26
# 34         291
# 35         153
# 36          74
# 37          14
# 38         107
# 39          31
# 40          50
# 41          54
# 42         170
# 43         250
# 44          85
# 45          51
# 46          41
# 47          83
# 48          99
# 49          40>

# %%
type(test['B09019_022E'].values[0])
# Out:
# str

# %%
test['B09019_022E'] = test['B09019_022E'].astype(int)

# %%
type(test['B09019_022E'].values[0])
# Out:
# numpy.int64

# %%
df2['household: foster_kids'] = test['B09019_022E']

# %%
df2
# Out:
#      Unnamed: 0  Year             County  Deaths  Population  Crude Rate  \
# 0             0  2015       Adams County      13       22006  Unreliable
# 1             1  2015       Allen County      21       82914        25.3
# 2             2  2015   Ashtabula County      24       79192        30.3
# 3             3  2015     Belmont County      18       57540  Unreliable
# 4             4  2015       Brown County      26       34930        74.4
# ..          ...   ...                ...     ...         ...         ...
# 245         245  2019  Tuscarawas County      15       73440  Unreliable
# 246         246  2019      Warren County      48      185077        25.9
# 247         247  2019  Washington County      11       49557  Unreliable
# 248         248  2019       Wayne County      24       90983        26.4
# 249         249  2019        Wood County      27      107311        25.2
#
#      Crude Rate Lower 95% Confidence Interval  \
# ...

# %%
# household data (combine) cleaning

# %%
dfhh19 = pd.read_csv(household_2019)

# %%
dfhh19 = dfhh19.rename(columns={"B09019_022E": "irrelavant"})
dfhh19 = dfhh19.rename(columns={"B09019_024E": "B09019_022E"})

dfhh19 = dfhh19.rename(columns={"B09019_005E": "B09019_027E"})
dfhh19 = dfhh19.rename(columns={"B09019_008E": "B09019_030E"})

dfhh19 = dfhh19.rename(columns={"B09019_026E": "B09019_038E"})

# %%
dfhh19.to_csv("household_2019_new.csv")

# %%
# household: foster kids

# %%
def delete_ohio(x):
    if x[-4:] == 'Ohio':
        return x[:-6]
    return x

# %%
def extract(file):
    
    def delete_ohio(x):
        if x[-4:] == 'Ohio':
            return x[:-6]
        return x
    
    df = pd.read_csv(file)
    df['NAME'] = df['NAME'].apply(delete_ohio)
    
    
    fileter = df.NAME.apply(lambda x: x in county) #county = df2.County.unique()
    final = df.copy()[fileter]
    final = final.iloc[:, :-1]
    
    cols = ['B09019_022E']
    result = final[cols]
    result = result.reset_index(drop=True)
    
    result[cols] = result[cols].astype(int)
    
    return pd.DataFrame(result[cols])

# %%
extract('household_2016.csv').head()
# Out:
#    B09019_022E
# 0            4
# 1            0
# 2           29
# 3           13
# 4            8

# %%
hhfiles = ['household_2015.csv', 'household_2016.csv', 'household_2017.csv',
         'household_2018.csv', 'household_2019_new.csv']

# %%
extract('household_2019_new.csv')
# Out:
#     B09019_022E
# 0             0
# 1           157
# 2            60
# 3            11
# 4            25
# 5           325
# 6           103
# 7           148
# 8            29
# 9            41
# 10          640
# 11           75
# 12           12
# 13            3
# 14           42
# 15          814
# 16            0
# 17           46
# 18          233
# 19         1549
# 20            3
# 21          101
# 22           34
# 23           80
# 24           64
# 25           52
# 26           99
# 27           29
# 28          156
# 29          465
# 30          200
# 31          150
# 32          102
# 33           73
# 34          353
# 35          141
# 36          155
# 37          107
# 38          217
# 39           57
# 40            0
# 41           63
# 42          515
# 43          375
# 44           51
# 45           62
# 46          109
# 47           23
# 48          173
# 49           40

# %%
def combine(files, answer=None):
    is_first = True
    for f in files:
        if is_first:
            is_first = False
            answer =extract(f)
        else:
            answer = pd.concat([answer, extract(f)])
    answer = answer.reset_index(drop=True)
    return answer

# %%
df2 = df2.reset_index(drop=True)

# %%
combine(hhfiles)
# Out:
#      B09019_022E
# 0              4
# 1              0
# 2             54
# 3             19
# 4             12
# ..           ...
# 245           62
# 246          109
# 247           23
# 248          173
# 249           40
#
# [250 rows x 1 columns]

# %%
df2['household: foster_kids'] = combine(hhfiles)

# %%
df2
# Out:
#      Unnamed: 0  Year             County  Deaths  Population  Crude Rate  \
# 0             0  2015       Adams County      13       22006  Unreliable
# 1             1  2015       Allen County      21       82914        25.3
# 2             2  2015   Ashtabula County      24       79192        30.3
# 3             3  2015     Belmont County      18       57540  Unreliable
# 4             4  2015       Brown County      26       34930        74.4
# ..          ...   ...                ...     ...         ...         ...
# 245         245  2019  Tuscarawas County      15       73440  Unreliable
# 246         246  2019      Warren County      48      185077        25.9
# 247         247  2019  Washington County      11       49557  Unreliable
# 248         248  2019       Wayne County      24       90983        26.4
# 249         249  2019        Wood County      27      107311        25.2
#
#      Crude Rate Lower 95% Confidence Interval  \
# ...

# %%
# household: people living alone

# %%
def delete_ohio(x):
    if x[-4:] == 'Ohio':
        return x[:-6]
    return x

# %%
def extract(file):
    
    def delete_ohio(x):
        if x[-4:] == 'Ohio':
            return x[:-6]
        return x
    
    df = pd.read_csv(file)
    df['NAME'] = df['NAME'].apply(delete_ohio)
    
    
    fileter = df.NAME.apply(lambda x: x in county) #county = df2.County.unique()
    final = df.copy()[fileter]
    final = final.iloc[:, :-1]
    
    cols = ['B09019_027E','B09019_030E']
    result = final[cols]
    result = result.reset_index(drop=True)
    
    result['B09019_027E'] = result['B09019_027E'].astype(int)
    result['B09019_030E'] = result['B09019_030E'].astype(int)

    result['sum'] = result.sum(axis=1) 
    
    return pd.DataFrame(result['sum'])

# %%
def combine(files, answer=None):
    is_first = True
    for f in files:
        if is_first:
            is_first = False
            answer =extract(f)
        else:
            answer = pd.concat([answer, extract(f)])
    answer = answer.reset_index(drop=True)
    return answer

# %%
df2 = df2.reset_index(drop=True)

# %%
hhfiles = ['household_2015.csv', 'household_2016.csv', 'household_2017.csv',
         'household_2018.csv', 'household_2019_new.csv']

# %%
combine(hhfiles)
# Out:
#        sum
# 0     2986
# 1    11468
# 2    11345
# 3     8644
# 4     3886
# ..     ...
# 245  10183
# 246  17158
# 247   7608
# 248  12045
# 249  14848
#
# [250 rows x 1 columns]

# %%
df2['household: people_living_alone'] = combine(hhfiles)

# %%
df2
# Out:
#      Unnamed: 0  Year             County  Deaths  Population  Crude Rate  \
# 0             0  2015       Adams County      13       22006  Unreliable
# 1             1  2015       Allen County      21       82914        25.3
# 2             2  2015   Ashtabula County      24       79192        30.3
# 3             3  2015     Belmont County      18       57540  Unreliable
# 4             4  2015       Brown County      26       34930        74.4
# ..          ...   ...                ...     ...         ...         ...
# 245         245  2019  Tuscarawas County      15       73440  Unreliable
# 246         246  2019      Warren County      48      185077        25.9
# 247         247  2019  Washington County      11       49557  Unreliable
# 248         248  2019       Wayne County      24       90983        26.4
# 249         249  2019        Wood County      27      107311        25.2
#
#      Crude Rate Lower 95% Confidence Interval  \
# ...

# %%
# household: in group quarters

# %%
def delete_ohio(x):
    if x[-4:] == 'Ohio':
        return x[:-6]
    return x

# %%
def extract(file):
    
    def delete_ohio(x):
        if x[-4:] == 'Ohio':
            return x[:-6]
        return x
    
    df = pd.read_csv(file)
    df['NAME'] = df['NAME'].apply(delete_ohio)
    
    
    fileter = df.NAME.apply(lambda x: x in county) #county = df2.County.unique()
    final = df.copy()[fileter]
    final = final.iloc[:, :-1]
    
    cols = ['B09019_038E']
    result = final[cols]
    result = result.reset_index(drop=True)
    
    result[cols] = result[cols].astype(int)
    
    return pd.DataFrame(result[cols])

# %%
hhfiles = ['household_2015.csv', 'household_2016.csv', 'household_2017.csv',
         'household_2018.csv', 'household_2019_new.csv']

# %%
def combine(files, answer=None):
    is_first = True
    for f in files:
        if is_first:
            is_first = False
            answer =extract(f)
        else:
            answer = pd.concat([answer, extract(f)])
    answer = answer.reset_index(drop=True)
    return answer

# %%
df2 = df2.reset_index(drop=True)

# %%
combine(hhfiles)
# Out:
#      B09019_038E
# 0            382
# 1           3917
# 2           3502
# 3           4044
# 4            581
# ..           ...
# 245         1092
# 246         7685
# 247         1660
# 248         4101
# 249         6845
#
# [250 rows x 1 columns]

# %%
df2['household: in_group_quarters'] = combine(hhfiles)

# %%
df2
# Out:
#      Unnamed: 0  Year             County  Deaths  Population  Crude Rate  \
# 0             0  2015       Adams County      13       22006  Unreliable
# 1             1  2015       Allen County      21       82914        25.3
# 2             2  2015   Ashtabula County      24       79192        30.3
# 3             3  2015     Belmont County      18       57540  Unreliable
# 4             4  2015       Brown County      26       34930        74.4
# ..          ...   ...                ...     ...         ...         ...
# 245         245  2019  Tuscarawas County      15       73440  Unreliable
# 246         246  2019      Warren County      48      185077        25.9
# 247         247  2019  Washington County      11       49557  Unreliable
# 248         248  2019       Wayne County      24       90983        26.4
# 249         249  2019        Wood County      27      107311        25.2
#
#      Crude Rate Lower 95% Confidence Interval  \
# ...

# %%
# household: nonrelatives in nonfamily households

# %%
def delete_ohio(x):
    if x[-4:] == 'Ohio':
        return x[:-6]
    return x

# %%
def extract(file):
    
    def delete_ohio(x):
        if x[-4:] == 'Ohio':
            return x[:-6]
        return x
    
    df = pd.read_csv(file)
    df['NAME'] = df['NAME'].apply(delete_ohio)
    
    
    fileter = df.NAME.apply(lambda x: x in county) #county = df2.County.unique()
    final = df.copy()[fileter]
    final = final.iloc[:, :-1]
    
    cols = ['B09019_037E','B09019_032E']
    result = final[cols]
    result = result.reset_index(drop=True)
    
    result['B09019_037E'] = result['B09019_037E'].astype(int)
    result['B09019_032E'] = result['B09019_032E'].astype(int)

    result['sum'] = result.sum(axis=1) 
    
    return pd.DataFrame(result['sum'])

# %%
extract('household_2015.csv')
# Out:
#       sum
# 0    1215
# 1    3970
# 2    3908
# 3    1932
# 4    1564
# 5   15166
# 6    5014
# 7    7325
# 8    1083
# 9    3288
# 10  45328
# 11   1020
# 12   3172
# 13   2474
# 14   3999
# 15  78702
# 16    681
# 17   2009
# 18   5952
# 19  38362
# 20   3057
# 21   2353
# 22   2149
# 23   2219
# 24   6991
# 25   1602
# 26   4640
# 27   1797
# 28   8609
# 29  20393
# 30   8136
# 31   1718
# 32   4417
# 33   3359
# 34  19644
# 35   2935
# 36   9894
# 37   1250
# 38   4534
# 39   2300
# 40   1998
# 41   4296
# 42  12181
# 43  20980
# 44   5312
# 45   2987
# 46   5128
# 47   1934
# 48   2264
# 49   8513

# %%
nonrelativesfiles = ['household_2015.csv', 'household_2016.csv', 'household_2017.csv',
         'household_2018.csv']

# %%
def combine(files, answer=None):
    is_first = True
    for f in files:
        if is_first:
            is_first = False
            answer =extract(f)
        else:
            answer = pd.concat([answer, extract(f)])
    answer = answer.reset_index(drop=True)
    return answer

# %%
combine(nonrelativesfiles)
# Out:
#       sum
# 0    1215
# 1    3970
# 2    3908
# 3    1932
# 4    1564
# ..    ...
# 195  3180
# 196  4715
# 197  1510
# 198  2425
# 199  8472
#
# [200 rows x 1 columns]

# %%
nonrelatives15_18 = combine(nonrelativesfiles)

# %%
nonrelatives15_18
# Out:
#       sum
# 0    1215
# 1    3970
# 2    3908
# 3    1932
# 4    1564
# ..    ...
# 195  3180
# 196  4715
# 197  1510
# 198  2425
# 199  8472
#
# [200 rows x 1 columns]

# %%
nonrelatives15_18.rename(columns={'sum':'B09019_025E'},inplace=True)

# %%
def extract19(file):
    
    def delete_ohio(x):
        if x[-4:] == 'Ohio':
            return x[:-6]
        return x
    
    df = pd.read_csv(file)
    df['NAME'] = df['NAME'].apply(delete_ohio)
    
    
    fileter = df.NAME.apply(lambda x: x in county) #county = df2.County.unique()
    final = df.copy()[fileter]
    final = final.iloc[:, :-1]
    
    cols = ['B09019_025E']
    result = final[cols]
    result = result.reset_index(drop=True)
    
    result[cols] = result[cols].astype(int)
    
    return pd.DataFrame(result[cols])

# %%
extract19('household_2019.csv')
# Out:
#     B09019_025E
# 0           872
# 1          2445
# 2          2412
# 3          1703
# 4           980
# 5         12635
# 6          3736
# 7          4446
# 8           801
# 9          2102
# 10        32062
# 11          701
# 12         3396
# 13         1898
# 14         3813
# 15        62723
# 16          688
# 17         1428
# 18         4947
# 19        28709
# 20         2090
# 21         1287
# 22         1899
# 23         1488
# 24         5489
# 25         1611
# 26         4625
# 27          719
# 28         7792
# 29        13458
# 30         4532
# 31         1521
# 32         2685
# 33         2913
# 34        13757
# 35         2563
# 36         6650
# 37          951
# 38         2856
# 39         1585
# 40         1469
# 41         2106
# 42         8676
# 43        14861
# 44         3225
# 45         1991
# 46         3094
# 47         1037
# 48         1975
# 49         6824

# %%
nonrelatives19 = extract19('household_2019.csv')

# %%
nonrelatives19
# Out:
#     B09019_025E
# 0           872
# 1          2445
# 2          2412
# 3          1703
# 4           980
# 5         12635
# 6          3736
# 7          4446
# 8           801
# 9          2102
# 10        32062
# 11          701
# 12         3396
# 13         1898
# 14         3813
# 15        62723
# 16          688
# 17         1428
# 18         4947
# 19        28709
# 20         2090
# 21         1287
# 22         1899
# 23         1488
# 24         5489
# 25         1611
# 26         4625
# 27          719
# 28         7792
# 29        13458
# 30         4532
# 31         1521
# 32         2685
# 33         2913
# 34        13757
# 35         2563
# 36         6650
# 37          951
# 38         2856
# 39         1585
# 40         1469
# 41         2106
# 42         8676
# 43        14861
# 44         3225
# 45         1991
# 46         3094
# 47         1037
# 48         1975
# 49         6824

# %%
concatenated = pd.concat([nonrelatives15_18, nonrelatives19])
concatenated = concatenated.reset_index(drop=True)
concatenated
# Out:
#      B09019_025E
# 0           1215
# 1           3970
# 2           3908
# 3           1932
# 4           1564
# ..           ...
# 245         1991
# 246         3094
# 247         1037
# 248         1975
# 249         6824
#
# [250 rows x 1 columns]

# %%
df2['household: nonrelatives_in_nonfamily_households'] = concatenated

# %%
df2
# Out:
#      Unnamed: 0  Year             County  Deaths  Population  Crude Rate  \
# 0             0  2015       Adams County      13       22006  Unreliable
# 1             1  2015       Allen County      21       82914        25.3
# 2             2  2015   Ashtabula County      24       79192        30.3
# 3             3  2015     Belmont County      18       57540  Unreliable
# 4             4  2015       Brown County      26       34930        74.4
# ..          ...   ...                ...     ...         ...         ...
# 245         245  2019  Tuscarawas County      15       73440  Unreliable
# 246         246  2019      Warren County      48      185077        25.9
# 247         247  2019  Washington County      11       49557  Unreliable
# 248         248  2019       Wayne County      24       90983        26.4
# 249         249  2019        Wood County      27      107311        25.2
#
#      Crude Rate Lower 95% Confidence Interval  \
# ...

# %%
df2.to_csv("combined_data.csv")
